# %% [markdown]
# # Working Locally VS in Google Colab

# %% [markdown]
# ### Working with your Jupyter Notebook **locally**

# %% [markdown]
# The recommended way to work is to clone the whole [repo](https://github.com/IriniKlz/DMLAP.git) and install the `dmlap` conda environment, that includes all the necessary packages for the respective project.

# %% [markdown]
# ### Working in **Google Colab**

# %% [markdown]
# If you choose to work on Google Colab, you should clone the repo inside your Google Drive. This way, you will have access to all notebooks in the same way as you would locally. If you do not clone the repo, you will have to upload the notebooks manually every time, together with any file/folder that might be needed, eg for your datasets and models.
#
# More info on that [here](https://colab.research.google.com/notebooks/io.ipynb).

# %% [markdown]
# You need to mount your drive to the machine:
#
# ```python
# from google.colab import drive
# drive.mount('/content/drive')
#
# # change directory using the os module
# import os
# os.chdir('drive/My Drive/')
# os.listdir()             # shows the contents of the current dir, you can use chdir again after that
# # os.mkdir("DMLAP") # creating a directory
# # os.chdir("DMLAP") # moving to this directory
# # os.getcwd()       # printing the current directory
# ```
#
# You can use git in Colab:
# ```python
# !git clone https://github.com/IriniKlz/DMLAP
# ```
#
# To pull updates from the upstream repository without losing your work:
# ```python
# !git stash     # temporary stashing away your changes
# !git pull      # importing the update from github
# !git stash pop # reimporting your changes, deleting the stash
# ```

# %% [markdown]
# **If you choose to run your notebooks in Google Colab, remember to start your notebooks with the cells above (no need to clone the repo every time).**
